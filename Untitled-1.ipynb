# %%
#importaçoes
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import KFold, cross_val_score, cross_validate
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import RobustScaler, StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.decomposition import IncrementalPCA
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
#exportar pra pdf 
# !pip install nbconvert PyPDF2
# !pip install joblib
import joblib
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: C:\Users\souza\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: C:\Users\souza\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
#caminho para pacote 
folder_path = 'C:\\Users\\souza\\Downloads\\projeto series temporais\\br_mme_consumo_energia_eletrica_uf.csv.gz'

# %%
#abrindo arquivo
df = pd.read_csv(folder_path, compression='gzip')
df
# Out:
#         ano  mes sigla_uf tipo_consumo  numero_consumidores  consumo
# 0      2004    1       TO        Total                  NaN    65876
# 1      2004    1       BA        Total                  NaN  1444451
# 2      2004    1       PR        Total                  NaN  1596274
# 3      2004    1       RS        Total                  NaN  1780912
# 4      2004    1       GO        Total                  NaN   630624
# ...     ...  ...      ...          ...                  ...      ...
# 38875  2023   12       BA  Residencial            5932740.0   718461
# 38876  2023   12       PA  Residencial            2614106.0   478726
# 38877  2023   12       AC  Residencial             245699.0    58301
# 38878  2023   12       RN  Residencial            1390080.0   210119
# 38879  2023   12       SC  Residencial            2719791.0   655389
#
# [38880 rows x 6 columns]

# %%
df.describe()
# Out:
#                 ano           mes  numero_consumidores       consumo
# count  38880.000000  38880.000000         2.592000e+04  3.888000e+04
# mean    2013.500000      6.500000         6.823034e+05  6.117320e+05
# std        5.766355      3.452097         1.839312e+06  1.208067e+06
# min     2004.000000      1.000000         5.200000e+01  3.540000e+02
# 25%     2008.750000      3.750000         1.895650e+04  8.547600e+04
# 50%     2013.500000      6.500000         1.081745e+05  2.210620e+05
# 75%     2018.250000      9.250000         4.424120e+05  5.966990e+05
# max     2023.000000     12.000000         1.920126e+07  1.280974e+07

# %%
df.isnull().sum()
# Out:
# ano                        0
# mes                        0
# sigla_uf                   0
# tipo_consumo               0
# numero_consumidores    12960
# consumo                    0
# dtype: int64

# %%
df['data'] = pd.to_datetime(df['ano'].astype(str) + '-' + df['mes'].astype(str) + '-01')
df = df.set_index(df['data'])

# %%
df
# Out:
#              ano  mes sigla_uf tipo_consumo  numero_consumidores  consumo  \
# data
# 2004-01-01  2004    1       TO        Total                  NaN    65876
# 2004-01-01  2004    1       BA        Total                  NaN  1444451
# 2004-01-01  2004    1       PR        Total                  NaN  1596274
# 2004-01-01  2004    1       RS        Total                  NaN  1780912
# 2004-01-01  2004    1       GO        Total                  NaN   630624
# ...          ...  ...      ...          ...                  ...      ...
# 2023-12-01  2023   12       BA  Residencial            5932740.0   718461
# 2023-12-01  2023   12       PA  Residencial            2614106.0   478726
# 2023-12-01  2023   12       AC  Residencial             245699.0    58301
# 2023-12-01  2023   12       RN  Residencial            1390080.0   210119
# 2023-12-01  2023   12       SC  Residencial            2719791.0   655389
#
#                  data
# data
# 2004-01-01 2004-01-01
# ...

# %%
df = df.drop('ano', axis=1)

# %%
df = df.drop('mes', axis=1)

# %%
df = df.drop('data', axis=1)

# %%
df
# Out:
#            sigla_uf tipo_consumo  numero_consumidores  consumo
# data
# 2004-01-01       TO        Total                  NaN    65876
# 2004-01-01       BA        Total                  NaN  1444451
# 2004-01-01       PR        Total                  NaN  1596274
# 2004-01-01       RS        Total                  NaN  1780912
# 2004-01-01       GO        Total                  NaN   630624
# ...             ...          ...                  ...      ...
# 2023-12-01       BA  Residencial            5932740.0   718461
# 2023-12-01       PA  Residencial            2614106.0   478726
# 2023-12-01       AC  Residencial             245699.0    58301
# 2023-12-01       RN  Residencial            1390080.0   210119
# 2023-12-01       SC  Residencial            2719791.0   655389
#
# [38880 rows x 4 columns]

# %%
sns.heatmap(df.isna())
#vamos tratar esse problema mais pra frente
# Out:
# <Axes: ylabel='data'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 38880 entries, 2004-01-01 to 2023-12-01
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   sigla_uf             38880 non-null  object
#  1   tipo_consumo         38880 non-null  object
#  2   numero_consumidores  25920 non-null  float64
#  3   consumo              38880 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.5+ MB

# %% [markdown]
# EDA

# %%
cat_col = df.select_dtypes(exclude=['number', 'datetime64[ns]']).columns
num_col = df.select_dtypes(exclude='object')

# %%
plt.figure(figsize=(10,6))
for cat in cat_col:
    plt.title(f'distribuiçao da coluna {cat}')
    sns.countplot(data=df, x=cat)
    plt.xticks(rotation=90)
    plt.show()

# %%
num_col
# Out:
#             numero_consumidores  consumo
# data
# 2004-01-01                  NaN    65876
# 2004-01-01                  NaN  1444451
# 2004-01-01                  NaN  1596274
# 2004-01-01                  NaN  1780912
# 2004-01-01                  NaN   630624
# ...                         ...      ...
# 2023-12-01            5932740.0   718461
# 2023-12-01            2614106.0   478726
# 2023-12-01             245699.0    58301
# 2023-12-01            1390080.0   210119
# 2023-12-01            2719791.0   655389
#
# [38880 rows x 2 columns]

# %%
#teste para saber se a serie é estacionaria ou n
result = adfuller(df['consumo'])
result = result[1]
if result <= 0.05:
    print('a serie é estacionaria')
else:
    print('nao é estacionaria')
# Out:
# a serie é estacionaria

# %% [markdown]
# Estudo forecast

# %%
# distribuiçao coluna consumo
plt.figure(figsize=(10,6))
sns.histplot(data=df, x='consumo')
plt.title('distribuiçao da coluna consumo')
plt.show()

# %%
#serie temporal
time_series = df['consumo']
plt.figure(figsize=(10,6))
sns.lineplot(time_series)
plt.title('distribuiçao da serie temporal')
plt.show()

# %%
#estudo media movel
def m_avg(time_series, dias, nome_coluna):
    plt.figure(figsize=(10,6))
    m_avg = time_series.rolling(dias).mean()
    sns.lineplot(m_avg, color='red', label='media movel')
    sns.lineplot(time_series, color='blue', label='serie real')
    plt.title(f'Média movel da timeseries {nome_coluna}')
    plt.legend(loc = 'best')
    plt.show()

# %%
#calculo de media movel em uma janela de 19 anos
m_avg(time_series, 6935, nome_coluna='consumo')

# %%
#sazonalidade 
def sazonalidade(time_series):
    plt.figure(figsize=(10,6))
    saz = time_series.diff()
    sns.lineplot(saz)
    plt.title('Sazonalidade da timeseries')
    plt.legend(loc='best')
    plt.show()
sazonalidade(time_series)
# Out:
# C:\Users\souza\AppData\Local\Temp\ipykernel_17548\899747462.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc='best')

# %%
#calculo de tendencia
def trend(time_series, window, min_periods):
    plt.figure(figsize=(10,6))
    trend = time_series.rolling(window=window,
                                center=True,
                                min_periods=min_periods).mean()
    
    sns.lineplot(time_series, color='blue', label='Consumo')
    sns.lineplot(trend, color='red', label='Tendencia')
    plt.title('Tendencia consumo energia eletrica Brasil')
    plt.show()

trend(time_series, 6935, 3468) #calculando tendencia em uma jandela de 19 anos

# %%
#ciclos 
y_cicles = time_series.rolling(180, center=True).std()
plt.figure(figsize=(10,6))
sns.lineplot(y_cicles)
plt.title('Analise de volatidade do consumo')
plt.show()

# %% [markdown]
# Engenharia de Atributos

# %%
#nessa parte, quero modelar a partir dos dados que tenho, uma soluçao para os valores nulos de numero_consumidores
df.isnull().sum()
# Out:
# sigla_uf                   0
# tipo_consumo               0
# numero_consumidores    12960
# consumo                    0
# dtype: int64

# %%
df['numero_consumidores'].shape
# Out:
# (38880,)

# %%
percent = (12960/38880)*100
print(f'cerca de {percent}% da coluna numero_consumidores sao dados nulos')
# Out:
# cerca de 33.33333333333333% da coluna numero_consumidores sao dados nulos

# %%
#teste de estacionaridade da coluna numero_consumidores
test = adfuller(df['numero_consumidores'].dropna())
test = test[1]
if test <= 0.05:
    print(f'a serie é estacionaria e com pvalor = {test}')
else:
    print('nao é estacionaria')
# Out:
# a serie é estacionaria e com pvalor = 6.823286109857503e-09

# %%
sns.lineplot(df['numero_consumidores'])
plt.title('coluna numero_consumidores com dados faltantes')
# Out:
# Text(0.5, 1.0, 'coluna numero_consumidores com dados faltantes')

# %%
df.isnull().sum()
# Out:
# sigla_uf                   0
# tipo_consumo               0
# numero_consumidores    12960
# consumo                    0
# dtype: int64

# %%
#metodo pd.interpolate()
df['numero_consumidores']= df['numero_consumidores'].interpolate(method='linear', limit_direction='backward')

# %%
df
# Out:
#            sigla_uf tipo_consumo  numero_consumidores  consumo
# data
# 2004-01-01       TO        Total              40857.0    65876
# 2004-01-01       BA        Total              40857.0  1444451
# 2004-01-01       PR        Total              40857.0  1596274
# 2004-01-01       RS        Total              40857.0  1780912
# 2004-01-01       GO        Total              40857.0   630624
# ...             ...          ...                  ...      ...
# 2023-12-01       BA  Residencial            5932740.0   718461
# 2023-12-01       PA  Residencial            2614106.0   478726
# 2023-12-01       AC  Residencial             245699.0    58301
# 2023-12-01       RN  Residencial            1390080.0   210119
# 2023-12-01       SC  Residencial            2719791.0   655389
#
# [38880 rows x 4 columns]

# %%
sns.lineplot(df['numero_consumidores'])
# Out:
# <Axes: xlabel='data', ylabel='numero_consumidores'>

# %%
#criaçao de nova coluna
df['consumo_medio_por_pessoa'] = df['consumo']/df['numero_consumidores']
df['variacao_de_consumo_por_pessoa'] = (df['consumo'].std())/df['consumo_medio_por_pessoa']
df
# Out:
#            sigla_uf tipo_consumo  numero_consumidores  consumo  \
# data
# 2004-01-01       TO        Total              40857.0    65876
# 2004-01-01       BA        Total              40857.0  1444451
# 2004-01-01       PR        Total              40857.0  1596274
# 2004-01-01       RS        Total              40857.0  1780912
# 2004-01-01       GO        Total              40857.0   630624
# ...             ...          ...                  ...      ...
# 2023-12-01       BA  Residencial            5932740.0   718461
# 2023-12-01       PA  Residencial            2614106.0   478726
# 2023-12-01       AC  Residencial             245699.0    58301
# 2023-12-01       RN  Residencial            1390080.0   210119
# 2023-12-01       SC  Residencial            2719791.0   655389
#
#             consumo_medio_por_pessoa  variacao_de_consumo_por_pessoa
# data
# 2004-01-01                  1.612355                    7.492560e+05
# ...

# %%
# df = df.drop('consumo_por_pessoa', axis=1)

# %%
df
# Out:
#            sigla_uf tipo_consumo  numero_consumidores  consumo  \
# data
# 2004-01-01       TO        Total              40857.0    65876
# 2004-01-01       BA        Total              40857.0  1444451
# 2004-01-01       PR        Total              40857.0  1596274
# 2004-01-01       RS        Total              40857.0  1780912
# 2004-01-01       GO        Total              40857.0   630624
# ...             ...          ...                  ...      ...
# 2023-12-01       BA  Residencial            5932740.0   718461
# 2023-12-01       PA  Residencial            2614106.0   478726
# 2023-12-01       AC  Residencial             245699.0    58301
# 2023-12-01       RN  Residencial            1390080.0   210119
# 2023-12-01       SC  Residencial            2719791.0   655389
#
#             consumo_medio_por_pessoa  variacao_de_consumo_por_pessoa
# data
# 2004-01-01                  1.612355                    7.492560e+05
# ...

# %%
#vizualizaçao de novas colunas 
sns.lineplot(df['consumo_medio_por_pessoa'])
plt.title('Consumo medio por pessoa')
plt.ylabel('consumo')
plt.show()

# %%
sns.lineplot(df['variacao_de_consumo_por_pessoa'])
plt.title('variacao consumo por pessoa')
plt.ylabel('consumo')
plt.show()

# %%
m_avg(df['consumo_medio_por_pessoa'], dias=365, nome_coluna='consumo medio por pessoa')

# %%
#separaçao das novas colunas numericas para analise de autocorrelaçao 
col_autocorrelation = df.select_dtypes(exclude='object')
col_autocorrelation
type(col_autocorrelation)
# Out:
# pandas.core.frame.DataFrame

# %%
#graficos de autocorrelaçao 
n_cols = len(col_autocorrelation.columns)  
fig, axes = plt.subplots(1, n_cols, figsize=(5 * n_cols, 5))  
for i, auto in enumerate(col_autocorrelation):
    ax = axes[i] if n_cols > 1 else axes
    plot_acf(col_autocorrelation[auto].values.squeeze(), lags=30, alpha=0.05, ax=ax)
    ax.set_title(f'autocorrelaçao: {auto}')
plt.tight_layout()
plt.show()

# %% [markdown]
# Modelagem

# %%
df.columns
# Out:
# Index(['sigla_uf', 'tipo_consumo', 'numero_consumidores', 'consumo',
#        'consumo_medio_por_pessoa', 'variacao_de_consumo_por_pessoa'],
#       dtype='object')

# %%
#variaveis para split
x = df.drop('consumo', axis=1)
y = df['consumo']

# %%
x.shape, y.shape
# Out:
# ((38880, 5), (38880,))

# %%
#verificando tipo de dado para entrar no pipe 
type(x), type(y)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 38880 entries, 2004-01-01 to 2023-12-01
# Data columns (total 6 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   sigla_uf                        38880 non-null  object
#  1   tipo_consumo                    38880 non-null  object
#  2   numero_consumidores             38880 non-null  float64
#  3   consumo                         38880 non-null  int64
#  4   consumo_medio_por_pessoa        38880 non-null  float64
#  5   variacao_de_consumo_por_pessoa  38880 non-null  float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 2.1+ MB

# %%
df
# Out:
#            sigla_uf tipo_consumo  numero_consumidores  consumo  \
# data
# 2004-01-01       TO        Total              40857.0    65876
# 2004-01-01       BA        Total              40857.0  1444451
# 2004-01-01       PR        Total              40857.0  1596274
# 2004-01-01       RS        Total              40857.0  1780912
# 2004-01-01       GO        Total              40857.0   630624
# ...             ...          ...                  ...      ...
# 2023-12-01       BA  Residencial            5932740.0   718461
# 2023-12-01       PA  Residencial            2614106.0   478726
# 2023-12-01       AC  Residencial             245699.0    58301
# 2023-12-01       RN  Residencial            1390080.0   210119
# 2023-12-01       SC  Residencial            2719791.0   655389
#
#             consumo_medio_por_pessoa  variacao_de_consumo_por_pessoa
# data
# 2004-01-01                  1.612355                    7.492560e+05
# ...

# %%
#separaçao colunas num e cat para pipe
n_attribs = ['numero_consumidores', 
                    # 'consumo',
                    'consumo_medio_por_pessoa',
                    'variacao_de_consumo_por_pessoa']


cat_attribs = ['sigla_uf', 'tipo_consumo']

# %%
#pre processamento
column_transf = ColumnTransformer([
    ('scaler_pca', Pipeline(steps=[
        ('scaler',StandardScaler()),
        ('pca', IncrementalPCA(n_components=3, batch_size=500))
    ]), n_attribs),  
    ('one_hot', OneHotEncoder(drop="if_binary", handle_unknown="ignore"), cat_attribs)  
])

# %%
#teste pipe
pipe = Pipeline(steps=[
    ('transform', column_transf),
    ('model', LinearRegression())
])
pipe
# Out:
# Pipeline(steps=[('transform',
#                  ColumnTransformer(transformers=[('scaler_pca',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler()),
#                                                                   ('pca',
#                                                                    IncrementalPCA(batch_size=500,
#                                                                                   n_components=3))]),
#                                                   ['numero_consumidores',
#                                                    'consumo_medio_por_pessoa',
#                                                    'variacao_de_consumo_por_pessoa']),
#                                                  ('one_hot',
#                                                   OneHotEncoder(drop='if_binary',
# ...

# %%
#separaçao x_test, y_test
train_size = 0.9  
split = int(len(x) * train_size)  
x_train, x_test = x[:split], x[split:]
y_train, y_test = y[:split], y[split:]

# %%
x_train
# Out:
#            sigla_uf tipo_consumo  numero_consumidores  \
# data
# 2004-01-01       TO        Total              40857.0
# 2004-01-01       BA        Total              40857.0
# 2004-01-01       PR        Total              40857.0
# 2004-01-01       RS        Total              40857.0
# 2004-01-01       GO        Total              40857.0
# ...             ...          ...                  ...
# 2021-12-01       SC  Residencial            2581156.0
# 2021-12-01       CE  Residencial            3060243.0
# 2021-12-01       SE  Residencial             874716.0
# 2021-12-01       MS  Residencial             988288.0
# 2021-12-01       PR  Residencial            4170754.0
#
#             consumo_medio_por_pessoa  variacao_de_consumo_por_pessoa
# data
# 2004-01-01                  1.612355                    7.492560e+05
# 2004-01-01                 35.353819                    3.417076e+04
# 2004-01-01                 39.069780                    3.092075e+04
# ...

# %%
x_train.shape, y_train.shape
# Out:
# ((34992, 5), (34992,))

# %%
x_test.shape, y_test.shape
# Out:
# ((3888, 5), (3888,))

# %%
#treino pipe
pipe.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('transform',
#                  ColumnTransformer(transformers=[('scaler_pca',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler()),
#                                                                   ('pca',
#                                                                    IncrementalPCA(batch_size=500,
#                                                                                   n_components=3))]),
#                                                   ['numero_consumidores',
#                                                    'consumo_medio_por_pessoa',
#                                                    'variacao_de_consumo_por_pessoa']),
#                                                  ('one_hot',
#                                                   OneHotEncoder(drop='if_binary',
# ...

# %%
#fazendo predicoes
pred = pipe.predict(x_test)
pred
# Out:
# array([ 456250.77522572, 1053090.85018388,  764033.16533718, ...,
#         -70548.25641451,  -40897.02018086,  584200.57025008])

# %%
#funçao que calcula metricas
def calculate_metrics(model, y_teste, pred):
    MAE = float(mean_absolute_error(y_teste, pred))
    R2 = float(r2_score(y_teste, pred))
    MSE = float(mean_squared_error(y_teste, pred))
    RMSE = float(np.sqrt(MSE))
    MAPE = float(mean_absolute_percentage_error(y_teste, pred))

    results = { 
        'modelo': model,
        'MAE': MAE,
        'R2_score': R2,
        'MSE': MSE,
        'RMSE': RMSE,
        'MAPE': MAPE
    }
    return results

# %%
calculate_metrics(pipe, y_test, pred)
# Out:
# {'modelo': Pipeline(steps=[('transform',
#                   ColumnTransformer(transformers=[('scaler_pca',
#                                                    Pipeline(steps=[('scaler',
#                                                                     StandardScaler()),
#                                                                    ('pca',
#                                                                     IncrementalPCA(batch_size=500,
#                                                                                    n_components=3))]),
#                                                    ['numero_consumidores',
#                                                     'consumo_medio_por_pessoa',
#                                                     'variacao_de_consumo_por_pessoa']),
#                                                   ('one_hot',
#                                                    OneHotEncoder(drop='if_binary',
# ...

# %%
#objeto com modelos 
models = {'linear_reg': LinearRegression(),
        # 'logistic_reg': LogisticRegression(solver='lbfgs'),
        'rforest_reg': RandomForestRegressor(),
        'gboost_reg': GradientBoostingRegressor(),
        'tree_reg': DecisionTreeRegressor(),
        'ada_reg': AdaBoostRegressor(),
}

# %%
#ve a variabilidade dos dados
sns.lineplot(y_train, color='blue')
sns.lineplot(y_test, color='red')
# Out:
# <Axes: xlabel='data', ylabel='consumo'>

# %%
#ponteiro para treinar modelos e prediçao 
predictions = {}
for i, (model_name, model) in enumerate(models.items()):
    pipe.set_params(model=model).fit(x_train,y_train)
    pred_ = pipe.predict(x_test)
    metrics = calculate_metrics(model=model, y_teste=y_test, pred=pred_)

    print(metrics)
# Out:
# {'modelo': LinearRegression(), 'MAE': 352171.5049885203, 'R2_score': 0.7090889724529164, 'MSE': 479086689365.3831, 'RMSE': 692160.8840185807, 'MAPE': 2.3741601492974604}
# {'modelo': RandomForestRegressor(), 'MAE': 51635.87493569959, 'R2_score': 0.9874672442331794, 'MSE': 20639562960.462845, 'RMSE': 143664.7589371271, 'MAPE': 0.06977940444215454}
# {'modelo': GradientBoostingRegressor(), 'MAE': 166968.3960881011, 'R2_score': 0.9454270697524284, 'MSE': 89873404599.7809, 'RMSE': 299788.93341779796, 'MAPE': 1.1289794974586338}
# {'modelo': DecisionTreeRegressor(), 'MAE': 53367.50051440329, 'R2_score': 0.9864471185009369, 'MSE': 22319556544.471706, 'RMSE': 149397.31103494368, 'MAPE': 0.07773276193126685}
# {'modelo': AdaBoostRegressor(), 'MAE': 403995.0644537873, 'R2_score': 0.817174246275869, 'MSE': 301086506829.81946, 'RMSE': 548713.5015924243, 'MAPE': 3.5928450263567275}

# %% [markdown]
# Cross validation

# %%
#definiçao de kf com kfolds
kf = KFold(n_splits=5, shuffle=True)

# %%
#cross val score
for i, cross_ in models.items():
    model_cross_val= pipe.set_params(model=cross_)
    cross_val = cross_val_score(model_cross_val, X=x_train, y=y_train, cv=kf, scoring='r2')
    print(f'metricas de cross do modelo {cross_} e R²:{cross_val}, com o valor max de: {cross_val.max()}')
# Out:
# metricas de cross do modelo LinearRegression() e R²:[0.71954098 0.71062041 0.73234093 0.69099274 0.69853485], com o valor max de: 0.7323409333062068
# metricas de cross do modelo RandomForestRegressor() e R²:[0.99791226 0.99742055 0.99765821 0.99743805 0.99726115], com o valor max de: 0.9979122552888596
# metricas de cross do modelo GradientBoostingRegressor() e R²:[0.98278247 0.98074755 0.98294142 0.98026288 0.9835192 ], com o valor max de: 0.9835192003171552
# metricas de cross do modelo DecisionTreeRegressor() e R²:[0.99504497 0.99588672 0.99539651 0.99416598 0.99501425], com o valor max de: 0.9958867225027912
# metricas de cross do modelo AdaBoostRegressor() e R²:[0.87591339 0.89487717 0.87214582 0.84835031 0.88199631], com o valor max de: 0.8948771680863656

# %% [markdown]
# previsao com os dois melhores modelos

# %%
#dicionario com melhores modelos 
best_models = [
    ("GradientBoosting", GradientBoostingRegressor()),
    ("RandomForest", RandomForestRegressor())
]

# %%
#separaçao de x_valid para validarmos 
sample_size = int(len(df) * 0.05)
x_valid = x[-sample_size:]
x_valid
# Out:
#            sigla_uf tipo_consumo  numero_consumidores  \
# data
# 2023-01-01       TO        Total         2.650917e+06
# 2023-01-01       PR        Total         2.647073e+06
# 2023-01-01       GO        Total         2.643229e+06
# 2023-01-01       MT        Total         2.639385e+06
# 2023-01-01       RJ        Total         2.635541e+06
# ...             ...          ...                  ...
# 2023-12-01       BA  Residencial         5.932740e+06
# 2023-12-01       PA  Residencial         2.614106e+06
# 2023-12-01       AC  Residencial         2.456990e+05
# 2023-12-01       RN  Residencial         1.390080e+06
# 2023-12-01       SC  Residencial         2.719791e+06
#
#             consumo_medio_por_pessoa  variacao_de_consumo_por_pessoa
# data
# 2023-01-01                  0.074993                    1.610900e+07
# 2023-01-01                  1.152819                    1.047924e+06
# 2023-01-01                  0.541298                    2.231795e+06
# ...

# %% [markdown]
# Avaliaçao

# %%
#pegando os 5% ultimos valores da serie para prediçoes
y_valid = time_series[-sample_size:]
sns.scatterplot(y_valid)
plt.title('distribuiçao 5% dos ultimos dados')
plt.show()

# %%
pipe.set_params(model=RandomForestRegressor()).fit(x_train, y_train)
# Out:
# Pipeline(steps=[('transform',
#                  ColumnTransformer(transformers=[('scaler_pca',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler()),
#                                                                   ('pca',
#                                                                    IncrementalPCA(batch_size=500,
#                                                                                   n_components=3))]),
#                                                   ['numero_consumidores',
#                                                    'consumo_medio_por_pessoa',
#                                                    'variacao_de_consumo_por_pessoa']),
#                                                  ('one_hot',
#                                                   OneHotEncoder(drop='if_binary',
# ...

# %%
pred_rforest = pipe.predict(x_valid)

# %%
plt.figure(figsize=(10,6))
plt.title('previsao modelo random forest')
plt.scatter(range(len(y_valid)), y_valid, label='y_valid', color='blue', alpha=0.6)
sns.lineplot(x=range(len(pred_rforest)), y=pred_rforest, label='random forest', color='orange', linestyle='--')
plt.show()

# %%
pipe.set_params(model=GradientBoostingRegressor()).fit(x_train, y_train)
# Out:
# Pipeline(steps=[('transform',
#                  ColumnTransformer(transformers=[('scaler_pca',
#                                                   Pipeline(steps=[('scaler',
#                                                                    RobustScaler()),
#                                                                   ('pca',
#                                                                    IncrementalPCA(batch_size=500,
#                                                                                   n_components=3))]),
#                                                   ['numero_consumidores',
#                                                    'consumo_medio_por_pessoa',
#                                                    'variacao_de_consumo_por_pessoa']),
#                                                  ('one_hot',
#                                                   OneHotEncoder(drop='if_binary',
# ...

# %%
pred_xgboost = pipe.predict(x_valid)

# %%
#graf xgboost 
plt.figure(figsize=(10,6))
plt.scatter(range(len(y_valid)), y_valid, label='y_valid', color='blue', alpha=0.6)
sns.lineplot(pred_xgboost, label='XGBoost', linestyle='--', color='orange')
plt.title('previsao modelo gradientgoosting')
plt.show()

# %% [markdown]
# salvar modelo

# %%
joblib.dump(RandomForestRegressor(),'modelo_RandomForest')
joblib.dump(GradientBoostingRegressor(), 'modelo_XGBoost')
# Out:
# ['modelo_XGBoost']
